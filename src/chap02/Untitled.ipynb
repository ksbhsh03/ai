# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =  pd.read_csv('titanic/train.csv')
df1 =  pd.read_csv('titanic/test.csv')

# %%
# Fare : 요금에 대한 정보 , pclass 티켓등급 , Sibsp 함께 탑승한 형제자매 배우자수, parch 함께탑승한 부모, 자식의수,
# Ticket 티켓번호, Cabin 객실번호, Embarked 탑승 항구 c Cherbourg, Q qeenstown S Southampton, Survived 생존여부
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#PassengerId	Pclass	Name	Sex	Age	SibSp	Parch	Ticket	Fare	Cabin	Embarked
# Fare : 요금에 대한 정보 , pclass 티켓등급 , Sibsp 함께 탑승한 형제자매 배우자수, parch 함께탑승한 부모, 자식의수,
# Ticket 티켓번호, Cabin 객실번호, Embarked 탑승 항구 c Cherbourg, Q qeenstown S Southampton, Survived


sns.barplot(data=df, x = 'Pclass', y='Survived')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# l(엘)mplot
sns.lmplot(x='Age', y='Sex', data= df, fit_reg=False,  # x축, y축, 데이터, line 없음
           scatter_kws = {'s':150}, # 좌표 상의 점의 크기
           markers = ['o', 'x'],
           hue = 'Survived') # 예측값
          
# title
plt.title('ST and 2P in 2d plane')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9524\3404311410.py in <module>
#       4            scatter_kws = {'s':150}, # 좌표 상의 점의 크기
#       5            markers = ['o', 'x'],
# ----> 6            hue = 'Survived') # 예측값
#       7
#       8 # title
#
# C:\ProgramData\Anaconda3\envs\tf_cpu\lib\site-packages\seaborn\regression.py in lmplot(data, x, y, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws)
#     622         ax.autoscale_view(scaley=False)
#     623
# --> 624     facets.map_dataframe(update_datalim, x=x, y=y)
#     625
# ...
