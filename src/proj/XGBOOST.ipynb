# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd   
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, log_loss

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier

# %%
import os
os.chdir('./open')
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')
submission=pd.read_csv('sample_submission.csv')

# %%
# 직업유형 삭제
train=train.drop('occyp_type', axis=1)
test=test.drop('occyp_type', axis=1)

# %%
train['gender'] = train['gender'].replace(['F','M'],[0,1])
test['gender'] = test['gender'].replace(['F','M'],[0,1])
print('gender :')
print(train['gender'].value_counts())
print('--------------')

# 차량 유무
print('Having a car or not : ')
train['car'] = train['car'].replace(['N','Y'],[0,1])
test['car'] = test['car'].replace(['N','Y'],[0,1])
print(train['car'].value_counts())
print('--------------')

# 자가 유무
print('Having house reality or not: ')
train['reality'] = train['reality'].replace(['N','Y'],[0,1])
test['reality'] = test['reality'].replace(['N','Y'],[0,1])
print(train['reality'].value_counts())
print('--------------')

#개인 핸드폰 유무
print('Having a phone or not: ')
print(train['phone'].value_counts())
print('--------------')
      
#이메일 유무
print('Having a email or not: ')
print(train['email'].value_counts())
print('--------------')
      
# 회사용 핸드폰유무
print('Having a work phone or not: ')
print(train['work_phone'].value_counts())
print('--------------')
# Out:
# gender :
# 0    17697
# 1     8760
# Name: gender, dtype: int64
# --------------
# Having a car or not :
# 0    16410
# 1    10047
# Name: car, dtype: int64
# --------------
# Having house reality or not:
# 1    17830
# 0     8627
# Name: reality, dtype: int64
# --------------
# Having a phone or not:
# 0    18672
# 1     7785
# Name: phone, dtype: int64
# --------------
# Having a email or not:
# 0    24042
# 1     2415
# Name: email, dtype: int64
# --------------
# Having a work phone or not:
# 0    20511
# 1     5946
# Name: work_phone, dtype: int64
# --------------

# %%
train.loc[train['child_num'] >= 2,'child_num']=2
test.loc[test['child_num']>=2, 'child_num']=2

# %%
count, bin_dividers =np.histogram(train['income_total'], bins=7)
bin_names=['소득'+str(i) for i in range(7) ]
#bin_dividers는 train기준!!
train['income_total']=pd.cut(x=train['income_total'], bins=bin_dividers, labels=bin_names, include_lowest=True)
test['income_total']=pd.cut(x=test['income_total'], bins=bin_dividers, labels=bin_names, include_lowest=True)

# %%
test
# Out:
#       index  gender  car  reality  child_num income_total  \
# 0     26457       1    1        0          0          소득0
# 1     26458       0    0        1          0          소득0
# 2     26459       0    0        1          0          소득0
# 3     26460       1    1        0          0          소득0
# 4     26461       0    1        1          0          소득0
# ...     ...     ...  ...      ...        ...          ...
# 9995  36452       0    1        1          0          소득0
# 9996  36453       1    1        1          0          소득0
# 9997  36454       0    0        1          0          소득1
# 9998  36455       0    1        0          0          소득0
# 9999  36456       0    0        1          0          소득1
#
#                income_type                       edu_type     family_type  \
# 0                Pensioner  Secondary / secondary special  Civil marriage
# 1            State servant               Higher education         Married
# 2                  Working  Secondary / secondary special         Married
# 3     Commercial associate  Secondary / secondary special         Married
# 4            State servant               Higher education         Married
# ...                    ...                            ...             ...
# 9995               Working              Incomplete higher         Married
# 9996               Working  Secondary / secondary special  Civil marriage
# 9997               Working  Secondary / secondary special         Married
# 9998  Commercial associate  Secondary / secondary special         Married
# 9999               Working               Higher education         Married
#
#              house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  \
# 0     House / apartment      -21990         365243           1           0
# 1     House / apartment      -18964          -8671           1           0
# 2     House / apartment      -15887           -217           1           1
# 3     House / apartment      -19270          -2531           1           1
# 4     House / apartment      -17822          -9385           1           1
# ...                 ...         ...            ...         ...         ...
# 9995  House / apartment      -18593          -5434           1           1
# 9996  House / apartment      -10886          -1315           1           1
# 9997  House / apartment      -21016         -14018           1           0
# 9998  House / apartment      -16541          -1085           1           0
# 9999  House / apartment       -9154           -187           1           0
#
#       phone  email  family_size  begin_month
# 0         1      0          2.0        -60.0
# 1         1      0          2.0        -36.0
# 2         1      0          2.0        -40.0
# 3         0      0          2.0        -41.0
# 4         0      0          2.0         -8.0
# ...     ...    ...          ...          ...
# 9995      1      0          2.0        -19.0
# 9996      0      0          2.0        -34.0
# 9997      0      0          2.0        -55.0
# 9998      1      0          2.0        -33.0
# 9999      0      1          2.0        -11.0
#
# [10000 rows x 18 columns]

# %%
print(train['income_type'].unique())
print(train['edu_type'].unique())
print(train['family_type'].unique())
print(train['house_type'].unique())
# Out:
# ['Commercial associate' 'Working' 'State servant' 'Pensioner' 'Student']
# ['Higher education' 'Secondary / secondary special' 'Incomplete higher'
#  'Lower secondary' 'Academic degree']
# ['Married' 'Civil marriage' 'Separated' 'Single / not married' 'Widow']
# ['Municipal apartment' 'House / apartment' 'With parents'
#  'Co-op apartment' 'Rented apartment' 'Office apartment']

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
train['income_type']=label_encoder.fit_transform(train['income_type'])
test['income_type']=label_encoder.transform(test['income_type'])
########################################################################
train['edu_type']=label_encoder.fit_transform(train['edu_type'])
test['edu_type']=label_encoder.transform(test['edu_type'])
########################################################################
train['family_type']=label_encoder.fit_transform(train['family_type'])
test['family_type']=label_encoder.transform(test['family_type'])
########################################################################
train['house_type']=label_encoder.fit_transform(train['house_type'])
test['house_type']=label_encoder.transform(test['house_type'])
########################################################################
train['income_total']=label_encoder.fit_transform(train['income_total'])
test['income_total']=label_encoder.fit_transform(test['income_total'])

# %%
#minus 변경하고
#구간화 함수
def make_bin(variable, n):
    train[variable]=-train[variable]
    test[variable]=-test[variable]
    count, bin_dividers =np.histogram(train[variable], bins=n) #train의 구간화를 적용
    bin_names=[str(i) for i in range(n)]
    train[variable]=pd.cut(x=train[variable], bins=bin_dividers, labels=bin_names, include_lowest=True)
    test[variable]=pd.cut(x=test[variable], bins=bin_dividers, labels=bin_names, include_lowest=True)
    test[variable].fillna(str(0), inplace=True) #test에는 없는 것을 임의의 값으로 채움
    ##########################################################
    train[variable]=label_encoder.fit_transform(train[variable])
    test[variable]=label_encoder.transform(test[variable])

# %%
train.columns
# Out:
# Index(['index', 'gender', 'car', 'reality', 'child_num', 'income_total',
#        'income_type', 'edu_type', 'family_type', 'house_type', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'FLAG_MOBIL', 'work_phone', 'phone', 'email',
#        'family_size', 'begin_month', 'credit'],
#       dtype='object')

# %%
make_bin('DAYS_BIRTH', n=8)
make_bin('DAYS_EMPLOYED', n=6)
make_bin('begin_month', n=4)

# %%
test
# Out:
#       index  gender  car  reality  child_num  income_total  income_type  \
# 0     26457       1    1        0          0             0            1
# 1     26458       0    0        1          0             0            2
# 2     26459       0    0        1          0             0            4
# 3     26460       1    1        0          0             0            0
# 4     26461       0    1        1          0             0            2
# ...     ...     ...  ...      ...        ...           ...          ...
# 9995  36452       0    1        1          0             0            4
# 9996  36453       1    1        1          0             0            4
# 9997  36454       0    0        1          0             1            4
# 9998  36455       0    1        0          0             0            0
# 9999  36456       0    0        1          0             1            4
#
#       edu_type  family_type  house_type  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0            4            0           1           6              0
# 1            1            1           1           5              1
# 2            4            1           1           3              1
# 3            4            1           1           5              1
# 4            1            1           1           4              1
# ...        ...          ...         ...         ...            ...
# 9995         2            1           1           4              1
# 9996         4            0           1           1              1
# 9997         4            1           1           6              1
# 9998         4            1           1           4              1
# 9999         1            1           1           0              1
#
#       FLAG_MOBIL  work_phone  phone  email  family_size  begin_month
# 0              1           0      1      0          2.0            3
# 1              1           0      1      0          2.0            2
# 2              1           1      1      0          2.0            2
# 3              1           1      0      0          2.0            2
# 4              1           1      0      0          2.0            0
# ...          ...         ...    ...    ...          ...          ...
# 9995           1           1      1      0          2.0            1
# 9996           1           1      0      0          2.0            2
# 9997           1           0      0      0          2.0            3
# 9998           1           0      1      0          2.0            2
# 9999           1           0      0      1          2.0            0
#
# [10000 rows x 18 columns]

# %%
train.shape
# Out:
# (26457, 19)

# %%
test.shape
# Out:
# (10000, 18)

# %%
train_x=train.drop('credit', axis=1)
train_y=train[['credit']]
test_x=test

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, log_loss
from sklearn.metrics import f1_score
from tensorflow.keras.utils import to_categorical

X_train, X_val, y_train, y_val = train_test_split(train_x, train_y, 
                                                    stratify=train_y, test_size=0.25,
                                                    random_state = 42)

print("Train set: ")
print(X_train.shape)
print(y_train.shape)
print("===========")
print("Validation set: ")
print(X_val.shape)
print(y_val.shape)


clf=XGBClassifier()
clf.fit(X_train, y_train)
y_pred=clf.predict_proba(X_val)

print(f"log_loss: {log_loss(to_categorical(y_val['credit']), y_pred)}")
# Out:
# Train set:
# (19842, 18)
# (19842, 1)
# ===========
# Validation set:
# (6615, 18)
# (6615, 1)
# [18:18:34] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# log_loss: 0.874686371140289

# %%
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3)  
xgb_wrapper.fit(X_train, y_train)
# Out:
# [18:18:38] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_delta_step=0,
#               max_depth=3, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=400, n_jobs=2,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=None,
#               subsample=1, tree_method='exact', validate_parameters=1,
#               verbosity=None)

# %%
w_preds = xgb_wrapper.predict(X_val)
w_pred_proba = xgb_wrapper.predict_proba(X_val)[:, 1]

# %%
from sklearn.metrics import accuracy_score # 정확도
from sklearn.metrics import precision_score, recall_score # 정밀도, 재현률
from sklearn.metrics import f1_score

def get_clf_eval(y_test, pred=None, pred_proba =None):
    accuracy = accuracy_score(y_val, pred)
    precision = precision_score(y_val, pred)
    recall = recall_score(y_val, pred)
    f1 = f1_score(y_val, pred)
    print('정확도: {0: .4f}, 정밀도:{1: .4f}, 재현율: {2: .4f}, F1:{3: .4f}'.format(accuracy, precision, recall, f1))

# %%
# 조기 종료(early stopping)을 제공
# verbose 학습의 결과값들을 logloss값을 출력해준다
# loss 값이 작아질수록 최적의 값을 찾아간다 어느순간에 그 값들이 변동이 없다 
# 100개까지 손실함수를 계산하면서 로스가 크게 변화가 없으면 더이상 학습하지않고 멈춰서 학습을 종료한다.
xgb_wrapper = XGBClassifier(n_estimators=1000, learning_rate=0.002, max_depth=7)  
evals = [(X_val, y_val)]
xgb_wrapper.fit(X_train, y_train, early_stopping_rounds=100, eval_set=evals, verbose=True)


ws100_preds = xgb_wrapper.predict(X_val)
ws100_pred_proba = xgb_wrapper.predict_proba(X_val)[:, 1]
# Out:
# [18:18:46] WARNING: ..\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-mlogloss:1.09787
# [1]	validation_0-mlogloss:1.09713
# [2]	validation_0-mlogloss:1.09639
# [3]	validation_0-mlogloss:1.09566
# [4]	validation_0-mlogloss:1.09493
# [5]	validation_0-mlogloss:1.09420
# [6]	validation_0-mlogloss:1.09347
# [7]	validation_0-mlogloss:1.09275
# [8]	validation_0-mlogloss:1.09203
# [9]	validation_0-mlogloss:1.09130
# [10]	validation_0-mlogloss:1.09059
# [11]	validation_0-mlogloss:1.08987
# [12]	validation_0-mlogloss:1.08916
# [13]	validation_0-mlogloss:1.08845
# [14]	validation_0-mlogloss:1.08775
# [15]	validation_0-mlogloss:1.08704
# [16]	validation_0-mlogloss:1.08634
# [17]	validation_0-mlogloss:1.08563
# [18]	validation_0-mlogloss:1.08494
# [19]	validation_0-mlogloss:1.08424
# [20]	validation_0-mlogloss:1.08355
# [21]	validation_0-mlogloss:1.08286
# [22]	validation_0-mlogloss:1.08217
# [23]	validation_0-mlogloss:1.08148
# [24]	validation_0-mlogloss:1.08080
# [25]	validation_0-mlogloss:1.08012
# [26]	validation_0-mlogloss:1.07944
# [27]	validation_0-mlogloss:1.07876
# [28]	validation_0-mlogloss:1.07809
# [29]	validation_0-mlogloss:1.07741
# [30]	validation_0-mlogloss:1.07674
# [31]	validation_0-mlogloss:1.07607
# [32]	validation_0-mlogloss:1.07541
# [33]	validation_0-mlogloss:1.07474
# [34]	validation_0-mlogloss:1.07408
# [35]	validation_0-mlogloss:1.07343
# [36]	validation_0-mlogloss:1.07277
# [37]	validation_0-mlogloss:1.07211
# [38]	validation_0-mlogloss:1.07145
# [39]	validation_0-mlogloss:1.07081
# [40]	validation_0-mlogloss:1.07015
# [41]	validation_0-mlogloss:1.06951
# [42]	validation_0-mlogloss:1.06886
# [43]	validation_0-mlogloss:1.06822
# [44]	validation_0-mlogloss:1.06758
# [45]	validation_0-mlogloss:1.06694
# [46]	validation_0-mlogloss:1.06630
# [47]	validation_0-mlogloss:1.06567
# [48]	validation_0-mlogloss:1.06504
# [49]	validation_0-mlogloss:1.06442
# [50]	validation_0-mlogloss:1.06379
# [51]	validation_0-mlogloss:1.06316
# [52]	validation_0-mlogloss:1.06255
# [53]	validation_0-mlogloss:1.06192
# [54]	validation_0-mlogloss:1.06130
# [55]	validation_0-mlogloss:1.06069
# [56]	validation_0-mlogloss:1.06008
# [57]	validation_0-mlogloss:1.05947
# [58]	validation_0-mlogloss:1.05886
# [59]	validation_0-mlogloss:1.05825
# [60]	validation_0-mlogloss:1.05764
# [61]	validation_0-mlogloss:1.05704
# [62]	validation_0-mlogloss:1.05644
# [63]	validation_0-mlogloss:1.05584
# [64]	validation_0-mlogloss:1.05523
# [65]	validation_0-mlogloss:1.05464
# [66]	validation_0-mlogloss:1.05405
# [67]	validation_0-mlogloss:1.05345
# [68]	validation_0-mlogloss:1.05286
# [69]	validation_0-mlogloss:1.05227
# [70]	validation_0-mlogloss:1.05169
# [71]	validation_0-mlogloss:1.05110
# [72]	validation_0-mlogloss:1.05052
# [73]	validation_0-mlogloss:1.04994
# [74]	validation_0-mlogloss:1.04936
# [75]	validation_0-mlogloss:1.04878
# [76]	validation_0-mlogloss:1.04820
# [77]	validation_0-mlogloss:1.04763
# [78]	validation_0-mlogloss:1.04706
# [79]	validation_0-mlogloss:1.04649
# [80]	validation_0-mlogloss:1.04592
# [81]	validation_0-mlogloss:1.04535
# [82]	validation_0-mlogloss:1.04478
# [83]	validation_0-mlogloss:1.04422
# [84]	validation_0-mlogloss:1.04366
# [85]	validation_0-mlogloss:1.04310
# [86]	validation_0-mlogloss:1.04254
# [87]	validation_0-mlogloss:1.04198
# [88]	validation_0-mlogloss:1.04143
# [89]	validation_0-mlogloss:1.04087
# [90]	validation_0-mlogloss:1.04032
# [91]	validation_0-mlogloss:1.03977
# [92]	validation_0-mlogloss:1.03922
# [93]	validation_0-mlogloss:1.03868
# [94]	validation_0-mlogloss:1.03813
# [95]	validation_0-mlogloss:1.03759
# [96]	validation_0-mlogloss:1.03705
# [97]	validation_0-mlogloss:1.03651
# [98]	validation_0-mlogloss:1.03597
# [99]	validation_0-mlogloss:1.03544
# [100]	validation_0-mlogloss:1.03490
# [101]	validation_0-mlogloss:1.03437
# [102]	validation_0-mlogloss:1.03384
# [103]	validation_0-mlogloss:1.03331
# [104]	validation_0-mlogloss:1.03279
# [105]	validation_0-mlogloss:1.03226
# [106]	validation_0-mlogloss:1.03173
# [107]	validation_0-mlogloss:1.03121
# [108]	validation_0-mlogloss:1.03070
# [109]	validation_0-mlogloss:1.03018
# [110]	validation_0-mlogloss:1.02966
# [111]	validation_0-mlogloss:1.02914
# [112]	validation_0-mlogloss:1.02863
# [113]	validation_0-mlogloss:1.02812
# [114]	validation_0-mlogloss:1.02761
# [115]	validation_0-mlogloss:1.02710
# [116]	validation_0-mlogloss:1.02659
# [117]	validation_0-mlogloss:1.02608
# [118]	validation_0-mlogloss:1.02558
# [119]	validation_0-mlogloss:1.02507
# [120]	validation_0-mlogloss:1.02457
# [121]	validation_0-mlogloss:1.02408
# [122]	validation_0-mlogloss:1.02358
# [123]	validation_0-mlogloss:1.02308
# [124]	validation_0-mlogloss:1.02259
# [125]	validation_0-mlogloss:1.02209
# [126]	validation_0-mlogloss:1.02160
# [127]	validation_0-mlogloss:1.02111
# [128]	validation_0-mlogloss:1.02063
# [129]	validation_0-mlogloss:1.02014
# [130]	validation_0-mlogloss:1.01966
# [131]	validation_0-mlogloss:1.01917
# [132]	validation_0-mlogloss:1.01869
# [133]	validation_0-mlogloss:1.01821
# [134]	validation_0-mlogloss:1.01774
# [135]	validation_0-mlogloss:1.01726
# [136]	validation_0-mlogloss:1.01679
# [137]	validation_0-mlogloss:1.01631
# [138]	validation_0-mlogloss:1.01584
# [139]	validation_0-mlogloss:1.01537
# [140]	validation_0-mlogloss:1.01490
# [141]	validation_0-mlogloss:1.01443
# [142]	validation_0-mlogloss:1.01396
# [143]	validation_0-mlogloss:1.01350
# [144]	validation_0-mlogloss:1.01304
# [145]	validation_0-mlogloss:1.01257
# [146]	validation_0-mlogloss:1.01211
# [147]	validation_0-mlogloss:1.01166
# [148]	validation_0-mlogloss:1.01120
# [149]	validation_0-mlogloss:1.01074
# [150]	validation_0-mlogloss:1.01029
# [151]	validation_0-mlogloss:1.00983
# [152]	validation_0-mlogloss:1.00938
# [153]	validation_0-mlogloss:1.00893
# [154]	validation_0-mlogloss:1.00848
# [155]	validation_0-mlogloss:1.00803
# [156]	validation_0-mlogloss:1.00758
# [157]	validation_0-mlogloss:1.00714
# [158]	validation_0-mlogloss:1.00669
# [159]	validation_0-mlogloss:1.00625
# [160]	validation_0-mlogloss:1.00581
# [161]	validation_0-mlogloss:1.00537
# [162]	validation_0-mlogloss:1.00493
# [163]	validation_0-mlogloss:1.00450
# [164]	validation_0-mlogloss:1.00406
# [165]	validation_0-mlogloss:1.00363
# [166]	validation_0-mlogloss:1.00319
# [167]	validation_0-mlogloss:1.00276
# [168]	validation_0-mlogloss:1.00233
# [169]	validation_0-mlogloss:1.00191
# [170]	validation_0-mlogloss:1.00148
# [171]	validation_0-mlogloss:1.00105
# [172]	validation_0-mlogloss:1.00063
# [173]	validation_0-mlogloss:1.00020
# [174]	validation_0-mlogloss:0.99978
# [175]	validation_0-mlogloss:0.99936
# [176]	validation_0-mlogloss:0.99894
# [177]	validation_0-mlogloss:0.99853
# [178]	validation_0-mlogloss:0.99811
# [179]	validation_0-mlogloss:0.99769
# [180]	validation_0-mlogloss:0.99728
# [181]	validation_0-mlogloss:0.99687
# [182]	validation_0-mlogloss:0.99645
# [183]	validation_0-mlogloss:0.99604
# [184]	validation_0-mlogloss:0.99563
# [185]	validation_0-mlogloss:0.99523
# [186]	validation_0-mlogloss:0.99482
# [187]	validation_0-mlogloss:0.99442
# [188]	validation_0-mlogloss:0.99401
# [189]	validation_0-mlogloss:0.99361
# [190]	validation_0-mlogloss:0.99321
# [191]	validation_0-mlogloss:0.99281
# [192]	validation_0-mlogloss:0.99241
# [193]	validation_0-mlogloss:0.99202
# [194]	validation_0-mlogloss:0.99162
# [195]	validation_0-mlogloss:0.99123
# [196]	validation_0-mlogloss:0.99083
# [197]	validation_0-mlogloss:0.99044
# [198]	validation_0-mlogloss:0.99005
# [199]	validation_0-mlogloss:0.98966
# [200]	validation_0-mlogloss:0.98927
# [201]	validation_0-mlogloss:0.98888
# [202]	validation_0-mlogloss:0.98850
# [203]	validation_0-mlogloss:0.98811
# [204]	validation_0-mlogloss:0.98773
# [205]	validation_0-mlogloss:0.98734
# [206]	validation_0-mlogloss:0.98696
# [207]	validation_0-mlogloss:0.98658
# [208]	validation_0-mlogloss:0.98620
# [209]	validation_0-mlogloss:0.98582
# [210]	validation_0-mlogloss:0.98545
# [211]	validation_0-mlogloss:0.98507
# [212]	validation_0-mlogloss:0.98470
# [213]	validation_0-mlogloss:0.98432
# [214]	validation_0-mlogloss:0.98395
# [215]	validation_0-mlogloss:0.98358
# [216]	validation_0-mlogloss:0.98321
# [217]	validation_0-mlogloss:0.98284
# [218]	validation_0-mlogloss:0.98248
# [219]	validation_0-mlogloss:0.98211
# [220]	validation_0-mlogloss:0.98175
# [221]	validation_0-mlogloss:0.98138
# [222]	validation_0-mlogloss:0.98102
# [223]	validation_0-mlogloss:0.98066
# [224]	validation_0-mlogloss:0.98030
# [225]	validation_0-mlogloss:0.97994
# [226]	validation_0-mlogloss:0.97958
# [227]	validation_0-mlogloss:0.97923
# [228]	validation_0-mlogloss:0.97887
# [229]	validation_0-mlogloss:0.97852
# [230]	validation_0-mlogloss:0.97816
# [231]	validation_0-mlogloss:0.97781
# [232]	validation_0-mlogloss:0.97746
# [233]	validation_0-mlogloss:0.97711
# [234]	validation_0-mlogloss:0.97676
# [235]	validation_0-mlogloss:0.97641
# [236]	validation_0-mlogloss:0.97606
# [237]	validation_0-mlogloss:0.97572
# [238]	validation_0-mlogloss:0.97537
# [239]	validation_0-mlogloss:0.97503
# [240]	validation_0-mlogloss:0.97469
# [241]	validation_0-mlogloss:0.97434
# [242]	validation_0-mlogloss:0.97401
# [243]	validation_0-mlogloss:0.97366
# [244]	validation_0-mlogloss:0.97332
# [245]	validation_0-mlogloss:0.97299
# [246]	validation_0-mlogloss:0.97265
# [247]	validation_0-mlogloss:0.97232
# [248]	validation_0-mlogloss:0.97198
# [249]	validation_0-mlogloss:0.97165
# [250]	validation_0-mlogloss:0.97132
# [251]	validation_0-mlogloss:0.97099
# [252]	validation_0-mlogloss:0.97066
# [253]	validation_0-mlogloss:0.97033
# [254]	validation_0-mlogloss:0.97000
# [255]	validation_0-mlogloss:0.96967
# [256]	validation_0-mlogloss:0.96934
# [257]	validation_0-mlogloss:0.96901
# [258]	validation_0-mlogloss:0.96869
# [259]	validation_0-mlogloss:0.96837
# [260]	validation_0-mlogloss:0.96804
# [261]	validation_0-mlogloss:0.96772
# [262]	validation_0-mlogloss:0.96740
# [263]	validation_0-mlogloss:0.96708
# [264]	validation_0-mlogloss:0.96676
# [265]	validation_0-mlogloss:0.96644
# [266]	validation_0-mlogloss:0.96612
# [267]	validation_0-mlogloss:0.96580
# [268]	validation_0-mlogloss:0.96549
# [269]	validation_0-mlogloss:0.96517
# [270]	validation_0-mlogloss:0.96486
# [271]	validation_0-mlogloss:0.96455
# [272]	validation_0-mlogloss:0.96423
# [273]	validation_0-mlogloss:0.96392
# [274]	validation_0-mlogloss:0.96361
# [275]	validation_0-mlogloss:0.96330
# [276]	validation_0-mlogloss:0.96299
# [277]	validation_0-mlogloss:0.96269
# [278]	validation_0-mlogloss:0.96238
# [279]	validation_0-mlogloss:0.96207
# [280]	validation_0-mlogloss:0.96177
# [281]	validation_0-mlogloss:0.96146
# [282]	validation_0-mlogloss:0.96116
# [283]	validation_0-mlogloss:0.96086
# [284]	validation_0-mlogloss:0.96056
# [285]	validation_0-mlogloss:0.96026
# [286]	validation_0-mlogloss:0.95996
# [287]	validation_0-mlogloss:0.95966
# [288]	validation_0-mlogloss:0.95936
# [289]	validation_0-mlogloss:0.95907
# [290]	validation_0-mlogloss:0.95877
# [291]	validation_0-mlogloss:0.95847
# [292]	validation_0-mlogloss:0.95818
# [293]	validation_0-mlogloss:0.95789
# [294]	validation_0-mlogloss:0.95760
# [295]	validation_0-mlogloss:0.95731
# [296]	validation_0-mlogloss:0.95702
# [297]	validation_0-mlogloss:0.95673
# [298]	validation_0-mlogloss:0.95644
# [299]	validation_0-mlogloss:0.95615
# [300]	validation_0-mlogloss:0.95586
# [301]	validation_0-mlogloss:0.95558
# [302]	validation_0-mlogloss:0.95529
# [303]	validation_0-mlogloss:0.95501
# [304]	validation_0-mlogloss:0.95473
# [305]	validation_0-mlogloss:0.95444
# [306]	validation_0-mlogloss:0.95416
# [307]	validation_0-mlogloss:0.95388
# [308]	validation_0-mlogloss:0.95360
# [309]	validation_0-mlogloss:0.95332
# [310]	validation_0-mlogloss:0.95304
# [311]	validation_0-mlogloss:0.95276
# [312]	validation_0-mlogloss:0.95249
# [313]	validation_0-mlogloss:0.95221
# [314]	validation_0-mlogloss:0.95194
# [315]	validation_0-mlogloss:0.95167
# [316]	validation_0-mlogloss:0.95139
# [317]	validation_0-mlogloss:0.95112
# [318]	validation_0-mlogloss:0.95085
# [319]	validation_0-mlogloss:0.95058
# [320]	validation_0-mlogloss:0.95030
# [321]	validation_0-mlogloss:0.95003
# [322]	validation_0-mlogloss:0.94977
# [323]	validation_0-mlogloss:0.94950
# [324]	validation_0-mlogloss:0.94923
# [325]	validation_0-mlogloss:0.94897
# [326]	validation_0-mlogloss:0.94871
# [327]	validation_0-mlogloss:0.94844
# [328]	validation_0-mlogloss:0.94817
# [329]	validation_0-mlogloss:0.94791
# [330]	validation_0-mlogloss:0.94765
# [331]	validation_0-mlogloss:0.94739
# [332]	validation_0-mlogloss:0.94712
# [333]	validation_0-mlogloss:0.94687
# [334]	validation_0-mlogloss:0.94661
# [335]	validation_0-mlogloss:0.94635
# [336]	validation_0-mlogloss:0.94609
# [337]	validation_0-mlogloss:0.94583
# [338]	validation_0-mlogloss:0.94558
# [339]	validation_0-mlogloss:0.94532
# [340]	validation_0-mlogloss:0.94507
# [341]	validation_0-mlogloss:0.94482
# [342]	validation_0-mlogloss:0.94456
# [343]	validation_0-mlogloss:0.94431
# [344]	validation_0-mlogloss:0.94406
# [345]	validation_0-mlogloss:0.94381
# [346]	validation_0-mlogloss:0.94357
# [347]	validation_0-mlogloss:0.94332
# [348]	validation_0-mlogloss:0.94307
# [349]	validation_0-mlogloss:0.94282
# [350]	validation_0-mlogloss:0.94258
# [351]	validation_0-mlogloss:0.94233
# [352]	validation_0-mlogloss:0.94208
# [353]	validation_0-mlogloss:0.94184
# [354]	validation_0-mlogloss:0.94160
# [355]	validation_0-mlogloss:0.94135
# [356]	validation_0-mlogloss:0.94111
# [357]	validation_0-mlogloss:0.94087
# [358]	validation_0-mlogloss:0.94063
# [359]	validation_0-mlogloss:0.94039
# [360]	validation_0-mlogloss:0.94015
# [361]	validation_0-mlogloss:0.93991
# [362]	validation_0-mlogloss:0.93968
# [363]	validation_0-mlogloss:0.93944
# [364]	validation_0-mlogloss:0.93920
# [365]	validation_0-mlogloss:0.93896
# [366]	validation_0-mlogloss:0.93873
# [367]	validation_0-mlogloss:0.93849
# [368]	validation_0-mlogloss:0.93826
# [369]	validation_0-mlogloss:0.93803
# [370]	validation_0-mlogloss:0.93780
# [371]	validation_0-mlogloss:0.93756
# [372]	validation_0-mlogloss:0.93734
# [373]	validation_0-mlogloss:0.93710
# [374]	validation_0-mlogloss:0.93688
# [375]	validation_0-mlogloss:0.93665
# [376]	validation_0-mlogloss:0.93642
# [377]	validation_0-mlogloss:0.93619
# [378]	validation_0-mlogloss:0.93596
# [379]	validation_0-mlogloss:0.93574
# [380]	validation_0-mlogloss:0.93551
# [381]	validation_0-mlogloss:0.93529
# [382]	validation_0-mlogloss:0.93506
# [383]	validation_0-mlogloss:0.93484
# [384]	validation_0-mlogloss:0.93462
# [385]	validation_0-mlogloss:0.93439
# [386]	validation_0-mlogloss:0.93417
# [387]	validation_0-mlogloss:0.93395
# [388]	validation_0-mlogloss:0.93373
# [389]	validation_0-mlogloss:0.93351
# [390]	validation_0-mlogloss:0.93329
# [391]	validation_0-mlogloss:0.93307
# [392]	validation_0-mlogloss:0.93285
# [393]	validation_0-mlogloss:0.93263
# [394]	validation_0-mlogloss:0.93241
# [395]	validation_0-mlogloss:0.93220
# [396]	validation_0-mlogloss:0.93198
# [397]	validation_0-mlogloss:0.93177
# [398]	validation_0-mlogloss:0.93155
# [399]	validation_0-mlogloss:0.93134
# [400]	validation_0-mlogloss:0.93112
# [401]	validation_0-mlogloss:0.93091
# [402]	validation_0-mlogloss:0.93070
# [403]	validation_0-mlogloss:0.93049
# [404]	validation_0-mlogloss:0.93027
# [405]	validation_0-mlogloss:0.93006
# [406]	validation_0-mlogloss:0.92985
# [407]	validation_0-mlogloss:0.92964
# [408]	validation_0-mlogloss:0.92943
# [409]	validation_0-mlogloss:0.92923
# [410]	validation_0-mlogloss:0.92902
# [411]	validation_0-mlogloss:0.92881
# [412]	validation_0-mlogloss:0.92861
# [413]	validation_0-mlogloss:0.92840
# [414]	validation_0-mlogloss:0.92819
# [415]	validation_0-mlogloss:0.92799
# [416]	validation_0-mlogloss:0.92779
# [417]	validation_0-mlogloss:0.92758
# [418]	validation_0-mlogloss:0.92738
# [419]	validation_0-mlogloss:0.92718
# [420]	validation_0-mlogloss:0.92698
# [421]	validation_0-mlogloss:0.92678
# [422]	validation_0-mlogloss:0.92658
# [423]	validation_0-mlogloss:0.92638
# [424]	validation_0-mlogloss:0.92618
# [425]	validation_0-mlogloss:0.92598
# [426]	validation_0-mlogloss:0.92579
# [427]	validation_0-mlogloss:0.92559
# [428]	validation_0-mlogloss:0.92539
# [429]	validation_0-mlogloss:0.92520
# [430]	validation_0-mlogloss:0.92500
# [431]	validation_0-mlogloss:0.92481
# [432]	validation_0-mlogloss:0.92462
# [433]	validation_0-mlogloss:0.92442
# [434]	validation_0-mlogloss:0.92423
# [435]	validation_0-mlogloss:0.92404
# [436]	validation_0-mlogloss:0.92385
# [437]	validation_0-mlogloss:0.92366
# [438]	validation_0-mlogloss:0.92346
# [439]	validation_0-mlogloss:0.92328
# [440]	validation_0-mlogloss:0.92309
# [441]	validation_0-mlogloss:0.92290
# [442]	validation_0-mlogloss:0.92271
# [443]	validation_0-mlogloss:0.92253
# [444]	validation_0-mlogloss:0.92234
# [445]	validation_0-mlogloss:0.92215
# [446]	validation_0-mlogloss:0.92197
# [447]	validation_0-mlogloss:0.92178
# [448]	validation_0-mlogloss:0.92160
# [449]	validation_0-mlogloss:0.92141
# [450]	validation_0-mlogloss:0.92123
# [451]	validation_0-mlogloss:0.92105
# [452]	validation_0-mlogloss:0.92087
# [453]	validation_0-mlogloss:0.92068
# [454]	validation_0-mlogloss:0.92050
# [455]	validation_0-mlogloss:0.92032
# [456]	validation_0-mlogloss:0.92014
# [457]	validation_0-mlogloss:0.91997
# [458]	validation_0-mlogloss:0.91979
# [459]	validation_0-mlogloss:0.91961
# [460]	validation_0-mlogloss:0.91943
# [461]	validation_0-mlogloss:0.91926
# [462]	validation_0-mlogloss:0.91908
# [463]	validation_0-mlogloss:0.91890
# [464]	validation_0-mlogloss:0.91873
# [465]	validation_0-mlogloss:0.91855
# [466]	validation_0-mlogloss:0.91838
# [467]	validation_0-mlogloss:0.91820
# [468]	validation_0-mlogloss:0.91803
# [469]	validation_0-mlogloss:0.91786
# [470]	validation_0-mlogloss:0.91768
# [471]	validation_0-mlogloss:0.91751
# [472]	validation_0-mlogloss:0.91734
# [473]	validation_0-mlogloss:0.91717
# [474]	validation_0-mlogloss:0.91700
# [475]	validation_0-mlogloss:0.91683
# [476]	validation_0-mlogloss:0.91665
# [477]	validation_0-mlogloss:0.91649
# [478]	validation_0-mlogloss:0.91632
# [479]	validation_0-mlogloss:0.91615
# [480]	validation_0-mlogloss:0.91598
# [481]	validation_0-mlogloss:0.91582
# [482]	validation_0-mlogloss:0.91565
# [483]	validation_0-mlogloss:0.91548
# [484]	validation_0-mlogloss:0.91532
# [485]	validation_0-mlogloss:0.91516
# [486]	validation_0-mlogloss:0.91499
# [487]	validation_0-mlogloss:0.91482
# [488]	validation_0-mlogloss:0.91466
# [489]	validation_0-mlogloss:0.91450
# [490]	validation_0-mlogloss:0.91433
# [491]	validation_0-mlogloss:0.91417
# [492]	validation_0-mlogloss:0.91402
# [493]	validation_0-mlogloss:0.91385
# [494]	validation_0-mlogloss:0.91369
# [495]	validation_0-mlogloss:0.91353
# [496]	validation_0-mlogloss:0.91337
# [497]	validation_0-mlogloss:0.91321
# [498]	validation_0-mlogloss:0.91306
# [499]	validation_0-mlogloss:0.91290
# [500]	validation_0-mlogloss:0.91274
# [501]	validation_0-mlogloss:0.91258
# [502]	validation_0-mlogloss:0.91243
# [503]	validation_0-mlogloss:0.91227
# [504]	validation_0-mlogloss:0.91211
# [505]	validation_0-mlogloss:0.91196
# [506]	validation_0-mlogloss:0.91180
# [507]	validation_0-mlogloss:0.91165
# [508]	validation_0-mlogloss:0.91149
# [509]	validation_0-mlogloss:0.91134
# [510]	validation_0-mlogloss:0.91119
# [511]	validation_0-mlogloss:0.91103
# [512]	validation_0-mlogloss:0.91088
# [513]	validation_0-mlogloss:0.91073
# [514]	validation_0-mlogloss:0.91058
# [515]	validation_0-mlogloss:0.91042
# [516]	validation_0-mlogloss:0.91028
# [517]	validation_0-mlogloss:0.91012
# [518]	validation_0-mlogloss:0.90998
# [519]	validation_0-mlogloss:0.90983
# [520]	validation_0-mlogloss:0.90968
# [521]	validation_0-mlogloss:0.90953
# [522]	validation_0-mlogloss:0.90938
# [523]	validation_0-mlogloss:0.90924
# [524]	validation_0-mlogloss:0.90909
# [525]	validation_0-mlogloss:0.90894
# [526]	validation_0-mlogloss:0.90880
# [527]	validation_0-mlogloss:0.90865
# [528]	validation_0-mlogloss:0.90851
# [529]	validation_0-mlogloss:0.90836
# [530]	validation_0-mlogloss:0.90822
# [531]	validation_0-mlogloss:0.90807
# [532]	validation_0-mlogloss:0.90793
# [533]	validation_0-mlogloss:0.90778
# [534]	validation_0-mlogloss:0.90765
# [535]	validation_0-mlogloss:0.90750
# [536]	validation_0-mlogloss:0.90736
# [537]	validation_0-mlogloss:0.90722
# [538]	validation_0-mlogloss:0.90707
# [539]	validation_0-mlogloss:0.90694
# [540]	validation_0-mlogloss:0.90679
# [541]	validation_0-mlogloss:0.90666
# [542]	validation_0-mlogloss:0.90652
# [543]	validation_0-mlogloss:0.90638
# [544]	validation_0-mlogloss:0.90624
# [545]	validation_0-mlogloss:0.90610
# [546]	validation_0-mlogloss:0.90597
# [547]	validation_0-mlogloss:0.90583
# [548]	validation_0-mlogloss:0.90570
# [549]	validation_0-mlogloss:0.90556
# [550]	validation_0-mlogloss:0.90543
# [551]	validation_0-mlogloss:0.90529
# [552]	validation_0-mlogloss:0.90515
# [553]	validation_0-mlogloss:0.90502
# [554]	validation_0-mlogloss:0.90488
# [555]	validation_0-mlogloss:0.90475
# [556]	validation_0-mlogloss:0.90462
# [557]	validation_0-mlogloss:0.90448
# [558]	validation_0-mlogloss:0.90436
# [559]	validation_0-mlogloss:0.90422
# [560]	validation_0-mlogloss:0.90409
# [561]	validation_0-mlogloss:0.90396
# [562]	validation_0-mlogloss:0.90383
# [563]	validation_0-mlogloss:0.90370
# [564]	validation_0-mlogloss:0.90357
# [565]	validation_0-mlogloss:0.90344
# [566]	validation_0-mlogloss:0.90331
# [567]	validation_0-mlogloss:0.90319
# [568]	validation_0-mlogloss:0.90306
# [569]	validation_0-mlogloss:0.90293
# [570]	validation_0-mlogloss:0.90280
# [571]	validation_0-mlogloss:0.90268
# [572]	validation_0-mlogloss:0.90256
# [573]	validation_0-mlogloss:0.90243
# [574]	validation_0-mlogloss:0.90230
# [575]	validation_0-mlogloss:0.90218
# [576]	validation_0-mlogloss:0.90205
# [577]	validation_0-mlogloss:0.90193
# [578]	validation_0-mlogloss:0.90180
# [579]	validation_0-mlogloss:0.90168
# [580]	validation_0-mlogloss:0.90156
# [581]	validation_0-mlogloss:0.90144
# [582]	validation_0-mlogloss:0.90131
# [583]	validation_0-mlogloss:0.90119
# [584]	validation_0-mlogloss:0.90107
# [585]	validation_0-mlogloss:0.90095
# [586]	validation_0-mlogloss:0.90083
# [587]	validation_0-mlogloss:0.90070
# [588]	validation_0-mlogloss:0.90058
# [589]	validation_0-mlogloss:0.90046
# [590]	validation_0-mlogloss:0.90034
# [591]	validation_0-mlogloss:0.90023
# [592]	validation_0-mlogloss:0.90010
# [593]	validation_0-mlogloss:0.89998
# [594]	validation_0-mlogloss:0.89987
# [595]	validation_0-mlogloss:0.89975
# [596]	validation_0-mlogloss:0.89963
# [597]	validation_0-mlogloss:0.89951
# [598]	validation_0-mlogloss:0.89939
# [599]	validation_0-mlogloss:0.89928
# [600]	validation_0-mlogloss:0.89916
# [601]	validation_0-mlogloss:0.89904
# [602]	validation_0-mlogloss:0.89892
# [603]	validation_0-mlogloss:0.89881
# [604]	validation_0-mlogloss:0.89869
# [605]	validation_0-mlogloss:0.89858
# [606]	validation_0-mlogloss:0.89846
# [607]	validation_0-mlogloss:0.89834
# [608]	validation_0-mlogloss:0.89823
# [609]	validation_0-mlogloss:0.89812
# [610]	validation_0-mlogloss:0.89800
# [611]	validation_0-mlogloss:0.89789
# [612]	validation_0-mlogloss:0.89778
# [613]	validation_0-mlogloss:0.89767
# [614]	validation_0-mlogloss:0.89755
# [615]	validation_0-mlogloss:0.89744
# [616]	validation_0-mlogloss:0.89733
# [617]	validation_0-mlogloss:0.89722
# [618]	validation_0-mlogloss:0.89711
# [619]	validation_0-mlogloss:0.89700
# [620]	validation_0-mlogloss:0.89689
# [621]	validation_0-mlogloss:0.89678
# [622]	validation_0-mlogloss:0.89667
# [623]	validation_0-mlogloss:0.89656
# [624]	validation_0-mlogloss:0.89645
# [625]	validation_0-mlogloss:0.89634
# [626]	validation_0-mlogloss:0.89623
# [627]	validation_0-mlogloss:0.89612
# [628]	validation_0-mlogloss:0.89602
# [629]	validation_0-mlogloss:0.89591
# [630]	validation_0-mlogloss:0.89580
# [631]	validation_0-mlogloss:0.89570
# [632]	validation_0-mlogloss:0.89559
# [633]	validation_0-mlogloss:0.89548
# [634]	validation_0-mlogloss:0.89538
# [635]	validation_0-mlogloss:0.89527
# [636]	validation_0-mlogloss:0.89516
# [637]	validation_0-mlogloss:0.89506
# [638]	validation_0-mlogloss:0.89495
# [639]	validation_0-mlogloss:0.89485
# [640]	validation_0-mlogloss:0.89475
# [641]	validation_0-mlogloss:0.89464
# [642]	validation_0-mlogloss:0.89454
# [643]	validation_0-mlogloss:0.89443
# [644]	validation_0-mlogloss:0.89433
# [645]	validation_0-mlogloss:0.89423
# [646]	validation_0-mlogloss:0.89413
# [647]	validation_0-mlogloss:0.89403
# [648]	validation_0-mlogloss:0.89393
# [649]	validation_0-mlogloss:0.89382
# [650]	validation_0-mlogloss:0.89372
# [651]	validation_0-mlogloss:0.89362
# [652]	validation_0-mlogloss:0.89352
# [653]	validation_0-mlogloss:0.89342
# [654]	validation_0-mlogloss:0.89332
# [655]	validation_0-mlogloss:0.89322
# [656]	validation_0-mlogloss:0.89312
# [657]	validation_0-mlogloss:0.89302
# [658]	validation_0-mlogloss:0.89292
# [659]	validation_0-mlogloss:0.89282
# [660]	validation_0-mlogloss:0.89272
# [661]	validation_0-mlogloss:0.89263
# [662]	validation_0-mlogloss:0.89253
# [663]	validation_0-mlogloss:0.89243
# [664]	validation_0-mlogloss:0.89233
# [665]	validation_0-mlogloss:0.89223
# [666]	validation_0-mlogloss:0.89214
# [667]	validation_0-mlogloss:0.89204
# [668]	validation_0-mlogloss:0.89194
# [669]	validation_0-mlogloss:0.89185
# [670]	validation_0-mlogloss:0.89175
# [671]	validation_0-mlogloss:0.89165
# [672]	validation_0-mlogloss:0.89156
# [673]	validation_0-mlogloss:0.89146
# [674]	validation_0-mlogloss:0.89137
# [675]	validation_0-mlogloss:0.89128
# [676]	validation_0-mlogloss:0.89118
# [677]	validation_0-mlogloss:0.89109
# [678]	validation_0-mlogloss:0.89100
# [679]	validation_0-mlogloss:0.89090
# [680]	validation_0-mlogloss:0.89081
# [681]	validation_0-mlogloss:0.89072
# [682]	validation_0-mlogloss:0.89062
# [683]	validation_0-mlogloss:0.89053
# [684]	validation_0-mlogloss:0.89044
# [685]	validation_0-mlogloss:0.89035
# [686]	validation_0-mlogloss:0.89026
# [687]	validation_0-mlogloss:0.89017
# [688]	validation_0-mlogloss:0.89008
# [689]	validation_0-mlogloss:0.88999
# [690]	validation_0-mlogloss:0.88989
# [691]	validation_0-mlogloss:0.88981
# [692]	validation_0-mlogloss:0.88972
# [693]	validation_0-mlogloss:0.88963
# [694]	validation_0-mlogloss:0.88954
# [695]	validation_0-mlogloss:0.88945
# [696]	validation_0-mlogloss:0.88937
# [697]	validation_0-mlogloss:0.88928
# [698]	validation_0-mlogloss:0.88919
# [699]	validation_0-mlogloss:0.88911
# [700]	validation_0-mlogloss:0.88902
# [701]	validation_0-mlogloss:0.88893
# [702]	validation_0-mlogloss:0.88885
# [703]	validation_0-mlogloss:0.88876
# [704]	validation_0-mlogloss:0.88868
# [705]	validation_0-mlogloss:0.88859
# [706]	validation_0-mlogloss:0.88851
# [707]	validation_0-mlogloss:0.88842
# [708]	validation_0-mlogloss:0.88834
# [709]	validation_0-mlogloss:0.88826
# [710]	validation_0-mlogloss:0.88818
# [711]	validation_0-mlogloss:0.88809
# [712]	validation_0-mlogloss:0.88801
# [713]	validation_0-mlogloss:0.88792
# [714]	validation_0-mlogloss:0.88784
# [715]	validation_0-mlogloss:0.88776
# [716]	validation_0-mlogloss:0.88768
# [717]	validation_0-mlogloss:0.88760
# [718]	validation_0-mlogloss:0.88752
# [719]	validation_0-mlogloss:0.88744
# [720]	validation_0-mlogloss:0.88736
# [721]	validation_0-mlogloss:0.88728
# [722]	validation_0-mlogloss:0.88720
# [723]	validation_0-mlogloss:0.88712
# [724]	validation_0-mlogloss:0.88704
# [725]	validation_0-mlogloss:0.88696
# [726]	validation_0-mlogloss:0.88688
# [727]	validation_0-mlogloss:0.88680
# [728]	validation_0-mlogloss:0.88672
# [729]	validation_0-mlogloss:0.88665
# [730]	validation_0-mlogloss:0.88657
# [731]	validation_0-mlogloss:0.88649
# [732]	validation_0-mlogloss:0.88642
# [733]	validation_0-mlogloss:0.88634
# [734]	validation_0-mlogloss:0.88626
# [735]	validation_0-mlogloss:0.88618
# [736]	validation_0-mlogloss:0.88611
# [737]	validation_0-mlogloss:0.88603
# [738]	validation_0-mlogloss:0.88595
# [739]	validation_0-mlogloss:0.88587
# [740]	validation_0-mlogloss:0.88580
# [741]	validation_0-mlogloss:0.88572
# [742]	validation_0-mlogloss:0.88565
# [743]	validation_0-mlogloss:0.88557
# [744]	validation_0-mlogloss:0.88550
# [745]	validation_0-mlogloss:0.88542
# [746]	validation_0-mlogloss:0.88535
# [747]	validation_0-mlogloss:0.88528
# [748]	validation_0-mlogloss:0.88520
# [749]	validation_0-mlogloss:0.88513
# [750]	validation_0-mlogloss:0.88506
# [751]	validation_0-mlogloss:0.88498
# [752]	validation_0-mlogloss:0.88491
# [753]	validation_0-mlogloss:0.88483
# [754]	validation_0-mlogloss:0.88476
# [755]	validation_0-mlogloss:0.88469
# [756]	validation_0-mlogloss:0.88462
# [757]	validation_0-mlogloss:0.88455
# [758]	validation_0-mlogloss:0.88447
# [759]	validation_0-mlogloss:0.88440
# [760]	validation_0-mlogloss:0.88433
# [761]	validation_0-mlogloss:0.88426
# [762]	validation_0-mlogloss:0.88419
# [763]	validation_0-mlogloss:0.88412
# [764]	validation_0-mlogloss:0.88405
# [765]	validation_0-mlogloss:0.88398
# [766]	validation_0-mlogloss:0.88391
# [767]	validation_0-mlogloss:0.88383
# [768]	validation_0-mlogloss:0.88376
# [769]	validation_0-mlogloss:0.88370
# [770]	validation_0-mlogloss:0.88362
# [771]	validation_0-mlogloss:0.88355
# [772]	validation_0-mlogloss:0.88348
# [773]	validation_0-mlogloss:0.88341
# [774]	validation_0-mlogloss:0.88334
# [775]	validation_0-mlogloss:0.88328
# [776]	validation_0-mlogloss:0.88321
# [777]	validation_0-mlogloss:0.88314
# [778]	validation_0-mlogloss:0.88307
# [779]	validation_0-mlogloss:0.88300
# [780]	validation_0-mlogloss:0.88293
# [781]	validation_0-mlogloss:0.88286
# [782]	validation_0-mlogloss:0.88279
# [783]	validation_0-mlogloss:0.88273
# [784]	validation_0-mlogloss:0.88266
# [785]	validation_0-mlogloss:0.88259
# [786]	validation_0-mlogloss:0.88252
# [787]	validation_0-mlogloss:0.88245
# [788]	validation_0-mlogloss:0.88239
# [789]	validation_0-mlogloss:0.88232
# [790]	validation_0-mlogloss:0.88225
# [791]	validation_0-mlogloss:0.88219
# [792]	validation_0-mlogloss:0.88212
# [793]	validation_0-mlogloss:0.88205
# [794]	validation_0-mlogloss:0.88199
# [795]	validation_0-mlogloss:0.88192
# [796]	validation_0-mlogloss:0.88186
# [797]	validation_0-mlogloss:0.88179
# [798]	validation_0-mlogloss:0.88173
# [799]	validation_0-mlogloss:0.88166
# [800]	validation_0-mlogloss:0.88160
# [801]	validation_0-mlogloss:0.88153
# [802]	validation_0-mlogloss:0.88147
# [803]	validation_0-mlogloss:0.88140
# [804]	validation_0-mlogloss:0.88134
# [805]	validation_0-mlogloss:0.88128
# [806]	validation_0-mlogloss:0.88121
# [807]	validation_0-mlogloss:0.88115
# [808]	validation_0-mlogloss:0.88109
# [809]	validation_0-mlogloss:0.88102
# [810]	validation_0-mlogloss:0.88096
# [811]	validation_0-mlogloss:0.88090
# [812]	validation_0-mlogloss:0.88084
# [813]	validation_0-mlogloss:0.88077
# [814]	validation_0-mlogloss:0.88071
# [815]	validation_0-mlogloss:0.88065
# [816]	validation_0-mlogloss:0.88059
# [817]	validation_0-mlogloss:0.88053
# [818]	validation_0-mlogloss:0.88047
# [819]	validation_0-mlogloss:0.88040
# [820]	validation_0-mlogloss:0.88034
# [821]	validation_0-mlogloss:0.88028
# [822]	validation_0-mlogloss:0.88022
# [823]	validation_0-mlogloss:0.88016
# [824]	validation_0-mlogloss:0.88011
# [825]	validation_0-mlogloss:0.88004
# [826]	validation_0-mlogloss:0.87998
# [827]	validation_0-mlogloss:0.87993
# [828]	validation_0-mlogloss:0.87987
# [829]	validation_0-mlogloss:0.87981
# [830]	validation_0-mlogloss:0.87975
# [831]	validation_0-mlogloss:0.87969
# [832]	validation_0-mlogloss:0.87963
# [833]	validation_0-mlogloss:0.87957
# [834]	validation_0-mlogloss:0.87951
# [835]	validation_0-mlogloss:0.87945
# [836]	validation_0-mlogloss:0.87939
# [837]	validation_0-mlogloss:0.87934
# [838]	validation_0-mlogloss:0.87928
# [839]	validation_0-mlogloss:0.87922
# [840]	validation_0-mlogloss:0.87916
# [841]	validation_0-mlogloss:0.87911
# [842]	validation_0-mlogloss:0.87905
# [843]	validation_0-mlogloss:0.87899
# [844]	validation_0-mlogloss:0.87893
# [845]	validation_0-mlogloss:0.87887
# [846]	validation_0-mlogloss:0.87882
# [847]	validation_0-mlogloss:0.87876
# [848]	validation_0-mlogloss:0.87870
# [849]	validation_0-mlogloss:0.87865
# [850]	validation_0-mlogloss:0.87859
# [851]	validation_0-mlogloss:0.87853
# [852]	validation_0-mlogloss:0.87848
# [853]	validation_0-mlogloss:0.87843
# [854]	validation_0-mlogloss:0.87837
# [855]	validation_0-mlogloss:0.87831
# [856]	validation_0-mlogloss:0.87826
# [857]	validation_0-mlogloss:0.87821
# [858]	validation_0-mlogloss:0.87815
# [859]	validation_0-mlogloss:0.87810
# [860]	validation_0-mlogloss:0.87804
# [861]	validation_0-mlogloss:0.87799
# [862]	validation_0-mlogloss:0.87793
# [863]	validation_0-mlogloss:0.87787
# [864]	validation_0-mlogloss:0.87782
# [865]	validation_0-mlogloss:0.87777
# [866]	validation_0-mlogloss:0.87772
# [867]	validation_0-mlogloss:0.87766
# [868]	validation_0-mlogloss:0.87761
# [869]	validation_0-mlogloss:0.87755
# [870]	validation_0-mlogloss:0.87750
# [871]	validation_0-mlogloss:0.87745
# [872]	validation_0-mlogloss:0.87740
# [873]	validation_0-mlogloss:0.87735
# [874]	validation_0-mlogloss:0.87730
# [875]	validation_0-mlogloss:0.87724
# [876]	validation_0-mlogloss:0.87719
# [877]	validation_0-mlogloss:0.87714
# [878]	validation_0-mlogloss:0.87709
# [879]	validation_0-mlogloss:0.87704
# [880]	validation_0-mlogloss:0.87699
# [881]	validation_0-mlogloss:0.87694
# [882]	validation_0-mlogloss:0.87689
# [883]	validation_0-mlogloss:0.87683
# [884]	validation_0-mlogloss:0.87678
# [885]	validation_0-mlogloss:0.87673
# [886]	validation_0-mlogloss:0.87668
# [887]	validation_0-mlogloss:0.87663
# [888]	validation_0-mlogloss:0.87658
# [889]	validation_0-mlogloss:0.87653
# [890]	validation_0-mlogloss:0.87648
# [891]	validation_0-mlogloss:0.87643
# [892]	validation_0-mlogloss:0.87639
# [893]	validation_0-mlogloss:0.87634
# [894]	validation_0-mlogloss:0.87629
# [895]	validation_0-mlogloss:0.87624
# [896]	validation_0-mlogloss:0.87619
# [897]	validation_0-mlogloss:0.87614
# [898]	validation_0-mlogloss:0.87610
# [899]	validation_0-mlogloss:0.87605
# [900]	validation_0-mlogloss:0.87600
# [901]	validation_0-mlogloss:0.87596
# [902]	validation_0-mlogloss:0.87591
# [903]	validation_0-mlogloss:0.87586
# [904]	validation_0-mlogloss:0.87581
# [905]	validation_0-mlogloss:0.87577
# [906]	validation_0-mlogloss:0.87572
# [907]	validation_0-mlogloss:0.87567
# [908]	validation_0-mlogloss:0.87563
# [909]	validation_0-mlogloss:0.87558
# [910]	validation_0-mlogloss:0.87553
# [911]	validation_0-mlogloss:0.87549
# [912]	validation_0-mlogloss:0.87544
# [913]	validation_0-mlogloss:0.87539
# [914]	validation_0-mlogloss:0.87535
# [915]	validation_0-mlogloss:0.87530
# [916]	validation_0-mlogloss:0.87526
# [917]	validation_0-mlogloss:0.87521
# [918]	validation_0-mlogloss:0.87517
# [919]	validation_0-mlogloss:0.87512
# [920]	validation_0-mlogloss:0.87508
# [921]	validation_0-mlogloss:0.87503
# [922]	validation_0-mlogloss:0.87498
# [923]	validation_0-mlogloss:0.87494
# [924]	validation_0-mlogloss:0.87489
# [925]	validation_0-mlogloss:0.87485
# [926]	validation_0-mlogloss:0.87480
# [927]	validation_0-mlogloss:0.87476
# [928]	validation_0-mlogloss:0.87472
# [929]	validation_0-mlogloss:0.87467
# [930]	validation_0-mlogloss:0.87463
# [931]	validation_0-mlogloss:0.87459
# [932]	validation_0-mlogloss:0.87454
# [933]	validation_0-mlogloss:0.87450
# [934]	validation_0-mlogloss:0.87446
# [935]	validation_0-mlogloss:0.87441
# [936]	validation_0-mlogloss:0.87437
# [937]	validation_0-mlogloss:0.87433
# [938]	validation_0-mlogloss:0.87428
# [939]	validation_0-mlogloss:0.87424
# [940]	validation_0-mlogloss:0.87420
# [941]	validation_0-mlogloss:0.87415
# [942]	validation_0-mlogloss:0.87411
# [943]	validation_0-mlogloss:0.87407
# [944]	validation_0-mlogloss:0.87402
# [945]	validation_0-mlogloss:0.87398
# [946]	validation_0-mlogloss:0.87394
# [947]	validation_0-mlogloss:0.87389
# [948]	validation_0-mlogloss:0.87385
# [949]	validation_0-mlogloss:0.87381
# [950]	validation_0-mlogloss:0.87377
# [951]	validation_0-mlogloss:0.87373
# [952]	validation_0-mlogloss:0.87369
# [953]	validation_0-mlogloss:0.87364
# [954]	validation_0-mlogloss:0.87360
# [955]	validation_0-mlogloss:0.87356
# [956]	validation_0-mlogloss:0.87352
# [957]	validation_0-mlogloss:0.87348
# [958]	validation_0-mlogloss:0.87344
# [959]	validation_0-mlogloss:0.87340
# [960]	validation_0-mlogloss:0.87336
# [961]	validation_0-mlogloss:0.87332
# [962]	validation_0-mlogloss:0.87328
# [963]	validation_0-mlogloss:0.87324
# [964]	validation_0-mlogloss:0.87320
# [965]	validation_0-mlogloss:0.87315
# [966]	validation_0-mlogloss:0.87311
# [967]	validation_0-mlogloss:0.87308
# [968]	validation_0-mlogloss:0.87304
# [969]	validation_0-mlogloss:0.87300
# [970]	validation_0-mlogloss:0.87296
# [971]	validation_0-mlogloss:0.87292
# [972]	validation_0-mlogloss:0.87288
# [973]	validation_0-mlogloss:0.87284
# [974]	validation_0-mlogloss:0.87280
# [975]	validation_0-mlogloss:0.87276
# [976]	validation_0-mlogloss:0.87272
# [977]	validation_0-mlogloss:0.87268
# [978]	validation_0-mlogloss:0.87264
# [979]	validation_0-mlogloss:0.87261
# [980]	validation_0-mlogloss:0.87257
# [981]	validation_0-mlogloss:0.87253
# [982]	validation_0-mlogloss:0.87249
# [983]	validation_0-mlogloss:0.87245
# [984]	validation_0-mlogloss:0.87242
# [985]	validation_0-mlogloss:0.87238
# [986]	validation_0-mlogloss:0.87234
# [987]	validation_0-mlogloss:0.87230
# [988]	validation_0-mlogloss:0.87227
# [989]	validation_0-mlogloss:0.87223
# [990]	validation_0-mlogloss:0.87218
# [991]	validation_0-mlogloss:0.87214
# [992]	validation_0-mlogloss:0.87210
# [993]	validation_0-mlogloss:0.87206
# [994]	validation_0-mlogloss:0.87203
# [995]	validation_0-mlogloss:0.87198
# [996]	validation_0-mlogloss:0.87195
# [997]	validation_0-mlogloss:0.87190
# [998]	validation_0-mlogloss:0.87187
# [999]	validation_0-mlogloss:0.87183

# %%
os.chdir('../baseline')

# %%
submission.to_csv('submission.csv', index=False)
