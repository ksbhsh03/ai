# %%
import pandas as pd
import random
import os
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing

# %%
np.random.seed(42)

# %%
def cross_validation(classifier, train_x, train_y):
    cv_scores =[]
    
    for i in range(10):
        scores = cross_val_score(classifier, train_x, train_y, cv=50, scoring='accuracy')  # 훈려데이터가 적을때 많이 사용된다. 
        cv_scores.append(scores.mean())
        
    return cv_scores

# %%
train = pd.read_csv('open/train.csv')
test = pd.read_csv('open/test.csv')

# %%
def get_x_y(df):
    if 'class' in df.columns:
        df_x = df.drop(columns=['id', 'class'])
        df_y = df['class']
        return df_x, df_y
    else:
        df_x = df.drop(columns=['id'])
        return df_x

# %%
train_x, train_y = get_x_y(train)
test_x = get_x_y(test)

# %%
class_le = preprocessing.LabelEncoder()
snp_le = preprocessing.LabelEncoder()
snp_col = [f'SNP_{str(x).zfill(2)}' for x in range(1,16)]

# %%
snp_data = []
for col in snp_col:
    snp_data += list(train_x[col].values)

# %%
train_y = class_le.fit_transform(train_y)
snp_le.fit(snp_data)
# Out:
# LabelEncoder()

# %%
for col in train_x.columns:
    if col in snp_col:
        train_x[col] = snp_le.transform(train_x[col])
        test_x[col] = snp_le.transform(test_x[col])

# %%
rt_cv_scores = cross_validation(RandomForestClassifier(), train_x, train_y)

# %%
cv_list = [
            ['random_forest', rt_cv_scores]
          ]

df = pd.DataFrame.from_dict(dict(cv_list))
df.plot()
# Out:
# <AxesSubplot:>

# %%
np.mean(rt_cv_scores)
# Out:
# 0.9546666666666667

# %%
clf = RandomForestClassifier(random_state=)
clf.fit(train_x, train_y)
# Out:
#   File "C:\Users\ksbhs\AppData\Local\Temp\ipykernel_3664\2297704607.py", line 1
#     clf = RandomForestClassifier(random_state=)
#                                               ^
# SyntaxError: invalid syntax

# %%
preds = clf.predict(test_x)

# %%
print(preds)

# %%
submit = pd.read_csv('open/sample_submission.csv')

# %%
submit['class'] = class_le.inverse_transform(preds)

# %%
submit.to_csv('./answer/submit10.csv', index=False)
